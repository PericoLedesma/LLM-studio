# %% [markdown]
# Usefull links:
#
# https://colab.research.google.com/drive/1gi2yDvvhUwLT7c8ZEXz6Yja3cG5P2owP?usp=sharing#scrollTo=4p6sGK-_SM-h

# %% [markdown]
# -------

# %% [markdown]
# ### Libraries

# %%
import os
import pandas as pd
import json

import openai
from openai import OpenAI
openai_api_key = os.environ.get("OPENAI_API_KEY")

# %% [markdown]
# ---------

# %% [markdown]
# #  OPENAI API call
#
# Required inputs:
# - `model`: the name of the model you want to use (e.g., `gpt-3.5-turbo`, `gpt-4`, `gpt-3.5-turbo-0613`, `gpt-3.5-turbo-16k-0613`)
# - `messages`: a list of message objects, where each object has two required fields:
#     - `role`: the role of the messenger (either `system`, `user`, or `assistant`)
#     - `content`: the content of the message (e.g., `Write me a beautiful poem`)
#
# Messages can also contain an optional `name` field, which give the messenger a name. E.g., `example-user`, `Alice`, `BlackbeardBot`. Names may not contain spaces.
#
# As of June 2023, you can also optionally submit a list of `functions` that tell GPT whether it can generate JSON to feed into a function. For details, see the [documentation](https://platform.openai.com/docs/guides/gpt/function-calling), [API reference](https://platform.openai.com/docs/api-reference/chat), or the Cookbook guide [How to call functions with chat models](How_to_call_functions_with_chat_models.ipynb).
#
# Typically, a conversation will start with a system message that tells the assistant how to behave, followed by alternating user and assistant messages, but you are not required to follow this format.

# %%
openai.api_key=openai_api_key
all_model= openai.models.list()

pd.DataFrame(list(all_model), columns=["id", "created", "object", "owned"]).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 openai.api_key=openai_api_key
# ----> 2 all_model= openai.models.list()
#       4 pd.DataFrame(list(all_model), columns=["id", "created", "object", "owned"]).head()
#
# File ~/anaconda3/envs/general/lib/python3.11/site-packages/openai/_utils/_proxy.py:20, in LazyProxy.__getattr__(self, attr)
#      19 def __getattr__(self, attr: str) -> object:
# ---> 20     proxied = self.__get_proxied__()
#      21     if isinstance(proxied, LazyProxy):
#      22         return proxied  # pyright: ignore
#
# File ~/anaconda3/envs/general/lib/python3.11/site-packages/openai/_utils/_proxy.py:55, in LazyProxy.__get_proxied__(self)
#      54 def __get_proxied__(self) -> T:
# ---> 55     return self.__load__()
#
# File ~/anaconda3/envs/general/lib/python3.11/site-packages/openai/_module_client.py:42, in ModelsProxy.__load__(self)
#      40 @override
#      41 def __load__(self) -> resources.Models:
# ---> 42     return _load_client().models
#
# File ~/anaconda3/envs/general/lib/python3.11/site-packages/openai/__init__.py:327, in _load_client()
#     311         _client = _AzureModuleClient(  # type: ignore
#     312             api_version=api_version,
#     313             azure_endpoint=azure_endpoint,
#    (...)
#     323             http_client=http_client,
#     324         )
#     325         return _client
# --> 327     _client = _ModuleClient(
#     328         api_key=api_key,
#     329         organization=organization,
#     330         project=project,
#     331         base_url=base_url,
#     332         timeout=timeout,
#     333         max_retries=max_retries,
#     334         default_headers=default_headers,
#     335         default_query=default_query,
#     336         http_client=http_client,
#     337     )
#     338     return _client
#     340 return _client
#
# File ~/anaconda3/envs/general/lib/python3.11/site-packages/openai/_client.py:123, in OpenAI.__init__(self, api_key, organization, project, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     120 if base_url is None:
#     121     base_url = f"https://api.openai.com/v1"
# --> 123 super().__init__(
#     124     version=__version__,
#     125     base_url=base_url,
#     126     max_retries=max_retries,
#     127     timeout=timeout,
#     128     http_client=http_client,
#     129     custom_headers=default_headers,
#     130     custom_query=default_query,
#     131     _strict_response_validation=_strict_response_validation,
#     132 )
#     134 self._default_stream_cls = Stream
#     136 self.completions = resources.Completions(self)
#
# File ~/anaconda3/envs/general/lib/python3.11/site-packages/openai/_base_client.py:844, in SyncAPIClient.__init__(self, version, base_url, max_retries, timeout, transport, proxies, limits, http_client, custom_headers, custom_query, _strict_response_validation)
#     827     raise TypeError(
#     828         f"Invalid `http_client` argument; Expected an instance of `httpx.Client` but got {type(http_client)}"
#     829     )
#     831 super().__init__(
#     832     version=version,
#     833     limits=limits,
#    (...)
#     842     _strict_response_validation=_strict_response_validation,
#     843 )
# --> 844 self._client = http_client or SyncHttpxClientWrapper(
#     845     base_url=base_url,
#     846     # cast to a valid type because mypy doesn't understand our type narrowing
#     847     timeout=cast(Timeout, timeout),
#     848     proxies=proxies,
#     849     transport=transport,
#     850     limits=limits,
#     851     follow_redirects=True,
#     852 )
#
# File ~/anaconda3/envs/general/lib/python3.11/site-packages/openai/_base_client.py:742, in _DefaultHttpxClient.__init__(self, **kwargs)
#     740 kwargs.setdefault("limits", DEFAULT_CONNECTION_LIMITS)
#     741 kwargs.setdefault("follow_redirects", True)
# --> 742 super().__init__(**kwargs)
#
# TypeError: Client.__init__() got an unexpected keyword argument 'proxies'

# %% [markdown]
# ---------

# %% [markdown]
# # Text generation models

# %%
client = OpenAI(api_key=openai_api_key)

# %%
response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {
      "role": "user",
      "content": "what is your name?"
    }
  ],
  temperature=1,
  max_tokens=256,
  top_p=1,  
  frequency_penalty=0,
  presence_penalty=0
)
print(response.choices[0].message.content)
# Out:
# I am an AI digital assistant created by a team of developers at OpenAI.

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-AyRdOeGg5biBrQnSsCr8uPpdREZCY', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='I am an AI digital assistant created by a team of developers at OpenAI.', role='assistant', function_call=None, tool_calls=None, refusal=None))], created=1738969270, model='gpt-3.5-turbo-0125', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=17, prompt_tokens=12, total_tokens=29, prompt_tokens_details={'cached_tokens': 0, 'audio_tokens': 0}, completion_tokens_details={'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}), service_tier='default')

# %%
response.choices
# Out:
# [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='I am an AI digital assistant created by a team of developers at OpenAI.', role='assistant', function_call=None, tool_calls=None, refusal=None))]

# %%
response.choices[0]
# Out:
# Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='I am an AI digital assistant created by a team of developers at OpenAI.', role='assistant', function_call=None, tool_calls=None, refusal=None))

# %%
response.choices[0].message.content
# Out:
# 'I am an AI digital assistant created by a team of developers at OpenAI.'

# %%
# example with a system message
response = client.chat.completions.create(
    model='gpt-4',
    messages=[
        {"role": "system", "content": "You are a helpful assistant who is obsessed with potatoes."},
        {"role": "user", "content": "write code that prints out Akshath Nagulapally"}
    ],
    temperature=0.3,
)
print(response.choices[0].message.content)
# Out:
# Sure, I can help with that. Here's a simple Python code that prints out "Akshath Nagulapally". But, let's make it a bit more interesting by adding a potato-themed twist to it.
#
# ```python
# print("Akshath Nagulapally loves potatoes!")
# ```
#
# This code will print out "Akshath Nagulapally loves potatoes!" when run. Because, who doesn't love potatoes, right? They're versatile, delicious, and can be prepared in so many ways!

# %% [markdown]
# ---------

# %% [markdown]
# # STREAMING

# %%
stream = client.chat.completions.create(
    model="gpt-4",
    messages=[{"role": "user", "content": "Say this is a test. Tell me a story"}],
    stream=True,
)
for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Once upon a time in the charming little town of Galloway, there was a school known far and wide for its prestigious reputation - Edgewood Academy. The centerpiece of Edgewood's acclaim was their annual Unity Test, a rigorous assessment testing proficiency in all subjects, given only to the most elite students in the tenth grade.
#
# This year, a humble student named Ethan prepared to take on the formidable Unity Test. Ethan was brilliant, but what set him apart was his insatiable curiosity and dedication, and his humble origins in the working class of Galloway. His school was full of children from lofty families, while Ethan's mother worked as a seamstress and father as a blacksmith.
#
# The weeks leading up to the Unity Test were intense. When he was not helping his parents at their work or performing his daily chores, he would be found under the old apple tree at the back of their small house, his nose deep in books.
#
# His classmates, born with silver spoons, hired the best tutors money could buy, confident in their assured success. However, Ethan had to rely on sheer determination and persistence. He spent sleepless nights studying by the dim light of a flickering candle, fueled by his unwavering dream of proving himself.
#
# On the day of the Unity Test, Ethan walked into Edgewood Academy with a nervous heartbeat but a fearless spirit. The test was gruelling, lasting for several hours, testing every bit of knowledge the students had acquired.
#
# As Ethan grabbed his quill and began answering the questions, he was relieved to find that he could answer them all. Cheers and curious whispers spread throughout the town as news of the blacksmith's son performing exceptionally well on the Unity Test began to circulate. His hours under the apple tree, with nothing but an oil lamp and his books, finally paid off.
#
# After weeks of anticipating the results, when they were finally declared, Ethan had topped the Unity Test, becoming the first student ever in the history of Edgewood Academy from a working-class family to achieve such a feat. The day marked a victory not only for Ethan for his tireless effort but for every student from humbler backgrounds who dared to dream.
#
# So, in the end, this Unity Test became a parable in Galloway, a tale to motivate, inspire, and remind everyone that success is determined by dedication and hard work, not by wealth or status.
